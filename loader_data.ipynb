# %% [markdown]
# # <br> <br> <b> Rynek nieruchmości w Polsce w latach 2015 - 2018 </b>
# ___

# %% [markdown]
# #### <i><font color = 'grey'> plik ładujący niezbędne dane </font></i> <br> <br>

# %%
import pandas as pd

import os

import numpy as np

import geopandas as gpd

# %%
def get_relative_path(path): # path to file to load
    norm_path = os.path.normpath(path) # normalize path to operative system that you are working on
    current_dir = os.getcwd() # path to loader file (main path)
    relative_path = os.path.join(current_dir, norm_path) # connect both paths
    return relative_path

# %%
unemp_rate = pd.read_excel(get_relative_path("Dane_GUS/Bezrobocie/stopa_bezrobocia_withPoland.xlsx"), sheet_name = "TABLICA", header = 0 )

popul = pd.read_excel(get_relative_path("Dane_GUS/Ludnosc/liczba_ludnosci_withPoland.xlsx"), sheet_name = "TABLICA", header = 0 )

aver_salary = pd.read_excel(get_relative_path("Dane_GUS/Wynagrodzenie/Wynagrodzenia_srednie_withPoland.xlsx"), sheet_name = "TABLICA", header = 0 )

inflation_rate = pd.read_excel(get_relative_path("Dane_GUS/Inflacja/wskaznik_cen_withPoland.xlsx"), sheet_name = "TABLICA", header = 0 )

prices = pd.read_excel(get_relative_path("Dane_GUS/Nieruchomosci/srenia_cena_mieszkan_withPoland.xlsx"), sheet_name = "TABLICA", header = 0 )

prices_new = pd.read_excel(get_relative_path("Dane_GUS/Nieruchomosci/srenia_cena_mieszkan_withPoland.xlsx"), sheet_name = "R_pierwotny", header = 0 )

prices_old = pd.read_excel(get_relative_path("Dane_GUS/Nieruchomosci/srenia_cena_mieszkan_withPoland.xlsx"), sheet_name = "R_wtorny", header = 0 )

prices_quarters = pd.read_excel(get_relative_path("Dane_GUS/Nieruchomosci/srenia_cena_mieszkan_withPoland.xlsx"), sheet_name = "Kwartalne", header = 0 )

sold = pd.read_excel(get_relative_path("Dane_GUS/Nieruchomosci/liczba_sprzedanych_mieszkan_withPoland.xlsx"), sheet_name = "TABLICA", header = 0 )

sold_new = pd.read_excel(get_relative_path("Dane_GUS/Nieruchomosci/liczba_sprzedanych_mieszkan_withPoland.xlsx"), sheet_name = "R_pierwotny", header = 0 )

sold_old = pd.read_excel(get_relative_path("Dane_GUS/Nieruchomosci/liczba_sprzedanych_mieszkan_withPoland.xlsx"), sheet_name = "R_wtorny", header = 0 )

sold_quarters = pd.read_excel(get_relative_path("Dane_GUS/Nieruchomosci/liczba_sprzedanych_mieszkan_withPoland.xlsx"), sheet_name = "Kwartalne", header = 0 )

prices_m2 = pd.read_excel(get_relative_path("Dane_GUS/Nieruchomosci/srednia_cena_mieszkan_za_m2_withPoland.xlsx"), sheet_name = "TABLICA", header = 0 )

prices_m2_old = pd.read_excel(get_relative_path("Dane_GUS/Nieruchomosci/srednia_cena_mieszkan_za_m2_withPoland.xlsx"), sheet_name = "R_wtorny", header = 0 )

prices_m2_new = pd.read_excel(get_relative_path("Dane_GUS/Nieruchomosci/srednia_cena_mieszkan_za_m2_withPoland.xlsx"), sheet_name = "R_pierwotny", header = 0 )

prices_m2_quarters = pd.read_excel(get_relative_path("Dane_GUS/Nieruchomosci/srednia_cena_mieszkan_za_m2_withPoland.xlsx"), sheet_name = "Kwartalne", header = 0 )

poland_data = gpd.read_file(r'D:\\Studia\Projekt\maps\Poland_Polygon.shp')

print("Data loading finished")
# Out:
# Data loading finished
